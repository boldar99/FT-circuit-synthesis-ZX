# %%
from fault_equivalent_rewrites import unfuse_n_3FE

import pyzx as zx
from pyzx import VertexType, EdgeType, Graph
from fault_equivalent_rewrites import *

N = 6

g = Graph()
v = g.add_vertex(VertexType.Z, 0, 0)
for i in range(N):
    nv = g.add_vertex(VertexType.BOUNDARY, (2 * (i // 2) - 4) * 1.0, (2 * (i % 2) - 1) * 5)
    g.add_edge((v, nv))

unfuse_n_4FE(g, v)
zx.draw(g)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 15
#      12     nv = g.add_vertex(VertexType.BOUNDARY, (2 * (i // 2) - 4) * 1.0, (2 * (i % 2) - 1) * 5)
#      13     g.add_edge((v, nv))
# ---> 15 unfuse_n_4FE(g, v)
#      16 zx.draw(g)
#
# File ~/PycharmProjects/FT-circuit-synthesis-ZX/fault_equivalent_rewrites.py:413, in unfuse_n_4FE(g, v)
#     407 # We need num_slots = num_edges * 1 >= targets
#     408 # num_edges = vertices * 3 / 2
#     409 # So, vertices * 3 / 2 >= targets => vertices >= targets * 2 / 3
#     410 # Since vertices must be even:
#     411 vertices = math.ceil((targets * 2 / 3) / 2) * 2  # = math.ceil(targets / 3) * 2
# --> 413 G = find_cubic_graph_with_local_cuts(vertices, 2, random_search=True, max_trials=10_000)
#     414 if G is None:
#     415     return False
#
# NameError: name 'find_cubic_graph_with_local_cuts' is not defined
