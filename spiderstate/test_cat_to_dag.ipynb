# %%
import networkx as nx
import stim

from cat_to_dag import *


# --- Example Usage ---
stim_circuit_str = """
    H 0
    CX 0 1 1 2 1 10 1 11 0 3 3 4 3 12 3 5 3 11
    M 11
    DETECTOR rec[-1]
    CX 3 6 3 7 7 13 3 14 0 8 0 9 9 13
    M 13
    DETECTOR rec[-1]
    CX 9 12
    M 12
    DETECTOR rec[-1]
    CX 0 14
    M 14
    DETECTOR rec[-1]
    CX 0 10
    M 10
    DETECTOR rec[-1]
"""

# Number of legs as defined in your prompt
NUM_LEGS = 10

cnot_dag = get_cnot_dag(stim_circuit_str, NUM_LEGS)
draw_cnot_dag(cnot_dag)
# Out:
# /Users/boldi/PycharmProjects/FT-circuit-synthesis-ZX/spiderstate/cat_to_dag.py:154: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import stim

stim.Circuit(stim_circuit_str).diagram('timeline-svg')
# Out:
# <svg viewBox="0 0 2464 1056"  version="1.1" xmlns="http://www.w3.org/2000/svg">
# <g id="qubit_lines">
# <path id="qubit_line:0" d="M64,64 L2432,64 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="64">q0</text>
# <path id="qubit_line:1" d="M64,128 L2432,128 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="128">q1</text>
# <path id="qubit_line:2" d="M64,192 L2432,192 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="192">q2</text>
# <path id="qubit_line:3" d="M64,256 L2432,256 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="256">q3</text>
# <path id="qubit_line:4" d="M64,320 L2432,320 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="320">q4</text>
# <path id="qubit_line:5" d="M64,384 L2432,384 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="384">q5</text>
# <path id="qubit_line:6" d="M64,448 L2432,448 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="448">q6</text>
# <path id="qubit_line:7" d="M64,512 L2432,512 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="512">q7</text>
# <path id="qubit_line:8" d="M64,576 L2432,576 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="576">q8</text>
# <path id="qubit_line:9" d="M64,640 L2432,640 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="640">q9</text>
# <path id="qubit_line:10" d="M64,704 L2432,704 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="704">q10</text>
# <path id="qubit_line:11" d="M64,768 L2432,768 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="768">q11</text>
# <path id="qubit_line:12" d="M64,832 L2432,832 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="832">q12</text>
# <path id="qubit_line:13" d="M64,896 L2432,896 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="896">q13</text>
# <path id="qubit_line:14" d="M64,960 L2432,960 " stroke="black"/>
# <text dominant-baseline="central" text-anchor="end" font-family="monospace" font-size="12" x="64" y="960">q14</text>
# </g>
# <rect x="80" y="48" width="32" height="32" stroke="black" fill="white"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="96" y="64">H</text>
# <path d="M160,64 L160,128 " stroke="black"/>
# <circle cx="160" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="160" cy="128" r="12" stroke="black" fill="white"/>
# <path d="M148,128 L172,128 M160,116 L160,140 " stroke="black"/>
# <path d="M224,128 L224,192 " stroke="black"/>
# <circle cx="224" cy="128" r="12" stroke="none" fill="black"/>
# <circle cx="224" cy="192" r="12" stroke="black" fill="white"/>
# <path d="M212,192 L236,192 M224,180 L224,204 " stroke="black"/>
# <path d="M288,128 L288,704 " stroke="black"/>
# <circle cx="288" cy="128" r="12" stroke="none" fill="black"/>
# <circle cx="288" cy="704" r="12" stroke="black" fill="white"/>
# <path d="M276,704 L300,704 M288,692 L288,716 " stroke="black"/>
# <path d="M352,128 L352,768 " stroke="black"/>
# <circle cx="352" cy="128" r="12" stroke="none" fill="black"/>
# <circle cx="352" cy="768" r="12" stroke="black" fill="white"/>
# <path d="M340,768 L364,768 M352,756 L352,780 " stroke="black"/>
# <path d="M416,64 L416,256 " stroke="black"/>
# <circle cx="416" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="416" cy="256" r="12" stroke="black" fill="white"/>
# <path d="M404,256 L428,256 M416,244 L416,268 " stroke="black"/>
# <path d="M480,256 L480,320 " stroke="black"/>
# <circle cx="480" cy="256" r="12" stroke="none" fill="black"/>
# <circle cx="480" cy="320" r="12" stroke="black" fill="white"/>
# <path d="M468,320 L492,320 M480,308 L480,332 " stroke="black"/>
# <path d="M544,256 L544,832 " stroke="black"/>
# <circle cx="544" cy="256" r="12" stroke="none" fill="black"/>
# <circle cx="544" cy="832" r="12" stroke="black" fill="white"/>
# <path d="M532,832 L556,832 M544,820 L544,844 " stroke="black"/>
# <path d="M608,256 L608,384 " stroke="black"/>
# <circle cx="608" cy="256" r="12" stroke="none" fill="black"/>
# <circle cx="608" cy="384" r="12" stroke="black" fill="white"/>
# <path d="M596,384 L620,384 M608,372 L608,396 " stroke="black"/>
# <path d="M672,256 L672,768 " stroke="black"/>
# <circle cx="672" cy="256" r="12" stroke="none" fill="black"/>
# <circle cx="672" cy="768" r="12" stroke="black" fill="white"/>
# <path d="M660,768 L684,768 M672,756 L672,780 " stroke="black"/>
# <rect x="720" y="752" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="736" y="768" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="736" y="748">rec[0]</text>
# <rect x="784" y="752" width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="864" y="768">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="864" y="748">D0 = rec[0]</text>
# <path d="M800,256 L800,448 " stroke="black"/>
# <circle cx="800" cy="256" r="12" stroke="none" fill="black"/>
# <circle cx="800" cy="448" r="12" stroke="black" fill="white"/>
# <path d="M788,448 L812,448 M800,436 L800,460 " stroke="black"/>
# <path d="M992,256 L992,512 " stroke="black"/>
# <circle cx="992" cy="256" r="12" stroke="none" fill="black"/>
# <circle cx="992" cy="512" r="12" stroke="black" fill="white"/>
# <path d="M980,512 L1004,512 M992,500 L992,524 " stroke="black"/>
# <path d="M1056,512 L1056,896 " stroke="black"/>
# <circle cx="1056" cy="512" r="12" stroke="none" fill="black"/>
# <circle cx="1056" cy="896" r="12" stroke="black" fill="white"/>
# <path d="M1044,896 L1068,896 M1056,884 L1056,908 " stroke="black"/>
# <path d="M1120,256 L1120,960 " stroke="black"/>
# <circle cx="1120" cy="256" r="12" stroke="none" fill="black"/>
# <circle cx="1120" cy="960" r="12" stroke="black" fill="white"/>
# <path d="M1108,960 L1132,960 M1120,948 L1120,972 " stroke="black"/>
# <path d="M1184,64 L1184,576 " stroke="black"/>
# <circle cx="1184" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="1184" cy="576" r="12" stroke="black" fill="white"/>
# <path d="M1172,576 L1196,576 M1184,564 L1184,588 " stroke="black"/>
# <path d="M1248,64 L1248,640 " stroke="black"/>
# <circle cx="1248" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="1248" cy="640" r="12" stroke="black" fill="white"/>
# <path d="M1236,640 L1260,640 M1248,628 L1248,652 " stroke="black"/>
# <path d="M1312,640 L1312,896 " stroke="black"/>
# <circle cx="1312" cy="640" r="12" stroke="none" fill="black"/>
# <circle cx="1312" cy="896" r="12" stroke="black" fill="white"/>
# <path d="M1300,896 L1324,896 M1312,884 L1312,908 " stroke="black"/>
# <rect x="1360" y="880" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1376" y="896" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="1376" y="876">rec[1]</text>
# <rect x="1424" y="880" width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="1504" y="896">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="1504" y="876">D1 = rec[1]</text>
# <path d="M1440,640 L1440,832 " stroke="black"/>
# <circle cx="1440" cy="640" r="12" stroke="none" fill="black"/>
# <circle cx="1440" cy="832" r="12" stroke="black" fill="white"/>
# <path d="M1428,832 L1452,832 M1440,820 L1440,844 " stroke="black"/>
# <rect x="1616" y="816" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1632" y="832" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="1632" y="812">rec[2]</text>
# <rect x="1680" y="816" width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="1760" y="832">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="1760" y="812">D2 = rec[2]</text>
# <path d="M1888,64 L1888,960 " stroke="black"/>
# <circle cx="1888" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="1888" cy="960" r="12" stroke="black" fill="white"/>
# <path d="M1876,960 L1900,960 M1888,948 L1888,972 " stroke="black"/>
# <rect x="1936" y="944" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="1952" y="960" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="1952" y="940">rec[3]</text>
# <rect x="2000" y="944" width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2080" y="960">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2080" y="940">D3 = rec[3]</text>
# <path d="M2016,64 L2016,704 " stroke="black"/>
# <circle cx="2016" cy="64" r="12" stroke="none" fill="black"/>
# <circle cx="2016" cy="704" r="12" stroke="black" fill="white"/>
# <path d="M2004,704 L2028,704 M2016,692 L2016,716 " stroke="black"/>
# <rect x="2192" y="688" width="32" height="32" stroke="black" fill="black"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="30" x="2208" y="704" fill="white">M</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2208" y="684">rec[4]</text>
# <rect x="2256" y="688" width="160" height="32" stroke="black" fill="lightgray"/>
# <text dominant-baseline="central" text-anchor="middle" font-family="monospace" font-size="16" x="2336" y="704">DETECTOR</text>
# <text text-anchor="middle" font-family="monospace" font-size="8" x="2336" y="684">D4 = rec[4]</text>
# </svg>
