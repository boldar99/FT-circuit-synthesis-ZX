# %%
import json
from cat_state.simulate import visualise_acceptance_heatmap

with open(f"simulation_data/simulation_results_t_7.json", "r") as f:
    collected_data = json.load(f)

visualise_acceptance_heatmap(collected_data)
